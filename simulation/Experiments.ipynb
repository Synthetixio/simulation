# %%
# Imports and configuration

import model
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
sns.set_style("ticks")

# %%
# Model Parameters

num_agents = 1000
ticks = 50

# %%
# Run the model here

havven = model.HavvenModel(num_agents)
for _ in tqdm(range(ticks)):
    havven.step()
# Out:
# 100%|██████████| 50/50 [00:02<00:00, 29.13it/s]

# %%
# Collect and plot the data

df = havven.collector.get_model_vars_dataframe()
df.plot()
sns.despine()
plt.show()

# %% [markdown]
# $\text{Something weird is happening here at tick ~23. Should determine what it is.}$

# %%
df[21:25]
# Out:
#      Curit Demand  Curit Supply  Escrowed Curits    Fiat Demand  Fiat Supply  \
# 21   75312.619649  1.114124e+06    885876.283834  850414.170985  6140.151406
# 22   82446.750687  1.038811e+06    961188.903482  844274.019579  6060.704530
# 23  128799.019415  0.000000e+00    990094.263981       0.000000  6059.459296
# 24  157704.379914  0.000000e+00    990094.263981       0.000000  6059.459296
#
#         Gini     Max Wealth  Min Wealth   Nomin Demand   Nomin Supply  \
# 21  0.732817  991141.237162        -6.0  263709.545181   69172.468243
# 22  0.732772  990388.110965        -6.0  194537.076938   76386.046157
# 23  0.732753  990099.057360        -6.0       0.000000  122739.560120
# 24  0.732753  990099.057360        -6.0       0.000000  151644.920618
#
#            Nomins     Wealth SD
# 21  885876.283834  31307.291641
# 22  961188.903482  31283.498126
# 23  990094.263981  31274.365980
# 24  990094.263981  31274.365980
